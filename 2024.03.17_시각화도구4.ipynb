# %%
# 라이브러리 불러오기
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup
from time import sleep

# 그래프 시각화
from matplotlib import font_manager
from matplotlib import rc
import matplotlib.pyplot as plt

# 지도 시각화
import folium

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# 한글 인코딩
rc('font', family='AppleGothic')
# 마이너스 부호 출력
plt.rcParams['axes.unicode_minus'] = False

# %%
# 지도 생성
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=13)
# 지도 저장
seoul_map.save('지도.html')

# %%
# 대학교 경도, 위도
df = pd.read_excel('./excel/서울지역 대학교 위치.xlsx')
df.head(3)
# Out:
#             학교명         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328

# %%
# 지도 객체
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=11)

# 마커
for idx in df.index:
    # 데이터
    name, lat, lon = df.loc[idx][['학교명', '위도', '경도']]
    # 마커 표시
    folium.Marker([lat, lon], popup=name).add_to(seoul_map)

# 파일 저장
seoul_map.save('서울지역 대학교 위치.html')
# 출력
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8abb4409461d69b82c90c3b55b363af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8abb4409461d69b82c90c3b55b363af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8abb4409461d69b82c90c3b55b363af = L.map(
#                 &quot;map_f8abb4409461d69b82c90c3b55b363af&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09b98b3f045c8d3745f8345483041fac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_09b98b3f045c8d3745f8345483041fac.addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#             var marker_f781b80fb357484f8abca2703b8d8b36 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#         var popup_d070e642348eb4527ad27706947703d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e1a5da21d942d357fbd3a150a0371bd = $(`&lt;div id=&quot;html_0e1a5da21d942d357fbd3a150a0371bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_d070e642348eb4527ad27706947703d9.setContent(html_0e1a5da21d942d357fbd3a150a0371bd);
#
#
#
#         marker_f781b80fb357484f8abca2703b8d8b36.bindPopup(popup_d070e642348eb4527ad27706947703d9)
#         ;
#
#
#
#
#             var marker_0107e95984d83ed1a9cea38e2443cda5 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#         var popup_064c8e5471b503a20e0d1220a028573b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c4680a62a095af4bdcfe39a9c2e8a7e = $(`&lt;div id=&quot;html_4c4680a62a095af4bdcfe39a9c2e8a7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_064c8e5471b503a20e0d1220a028573b.setContent(html_4c4680a62a095af4bdcfe39a9c2e8a7e);
#
#
#
#         marker_0107e95984d83ed1a9cea38e2443cda5.bindPopup(popup_064c8e5471b503a20e0d1220a028573b)
#         ;
#
#
#
#
#             var marker_126273fc87ba7ea6a3ebb8011fc05bf5 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#         var popup_ef7b64afb747e22ca86728a3297bd740 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2d2557315a31dfaafbd8350ce9a7bf7 = $(`&lt;div id=&quot;html_f2d2557315a31dfaafbd8350ce9a7bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_ef7b64afb747e22ca86728a3297bd740.setContent(html_f2d2557315a31dfaafbd8350ce9a7bf7);
#
#
#
#         marker_126273fc87ba7ea6a3ebb8011fc05bf5.bindPopup(popup_ef7b64afb747e22ca86728a3297bd740)
#         ;
#
#
#
#
#             var marker_567fe2c5162763cdf49ae899a5362650 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#         var popup_4a4b871dc24551c56fba502a34f7dc7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddaee4debf3aed10449e8753d157cec9 = $(`&lt;div id=&quot;html_ddaee4debf3aed10449e8753d157cec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_4a4b871dc24551c56fba502a34f7dc7f.setContent(html_ddaee4debf3aed10449e8753d157cec9);
#
#
#
#         marker_567fe2c5162763cdf49ae899a5362650.bindPopup(popup_4a4b871dc24551c56fba502a34f7dc7f)
#         ;
#
#
#
#
#             var marker_2f8e21e70b7e92b1ad8580c4bd80c6d7 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
#
#
#         var popup_f188e8d1c4c0f638a805f081c44716bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9265cf75b23b89686f33a7ce5a7090a4 = $(`&lt;div id=&quot;html_9265cf75b23b89686f33a7ce5a7090a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_f188e8d1c4c0f638a805f081c44716bf.setContent(html_9265cf75b23b89686f33a7ce5a7090a4);
#
#
#
#         marker_2f8e21e70b7e92b1ad8580c4bd80c6d7.bindPopup(popup_f188e8d1c4c0f638a805f081c44716bf)
#         ;
#
#
#
#
#             var marker_6221633c2c4ca2545657c616f06e775d = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_f8abb4409461d69b82c90c3b55b363af);
